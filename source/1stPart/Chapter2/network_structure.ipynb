# %% [markdown]
# # 2.1 网络结构

# %% [markdown]
# ![](Pictures/2-1-1.jpg)

# %% [markdown]
# ## 2.1.1 实验数据与网络

# %% [markdown]
# ## 2.1.2 特征变换

# %% [markdown]
# ## 2.1.3 特征空间的划分

# %% [markdown]
# ## 2.1.4 激活编码
